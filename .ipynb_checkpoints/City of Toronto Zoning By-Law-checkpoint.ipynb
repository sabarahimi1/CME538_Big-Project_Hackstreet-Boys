# %% [markdown]
# # City of Toronto Zoning By-Law Data

# %% [markdown]
# The City of Toronto's Zoning By-law dataset, available on the Open Data Portal, provides information on zoning regulations within the city. This dataset is essential for understanding land use designations, building requirements, and permissible activities across different zones in Toronto. It serves as a valuable resource for urban planners, developers, and residents interested in the city's zoning framework.
#
# The dataset includes the following details:
# 1. Zone Classifications: Categories such as residential, commercial, industrial, and mixed-use zones with subcategories that further define land use within each zone.
# 2. Permitted Uses: Lists of activities allowed in each zone (e.g., residential dwellings, retail spaces, or manufacturing facilities).
# 3. Holding status for the zone.
# 5. Building Regulations: Maximum building heights, floor area ratios, maximum number of dwelling units, and density limits. Setback requirements and lot coverage specifications.
# 6. Overlay zones: Additional regulations for specific areas, like heritage conservation districts or floodplains.
# 7. Special Exceptions to zoning rules.
# 8. Geospatial data that includes zoning boundries and spatial attributes.
# 9. Administrative details: Relevant by-law numbers and dates of enactment, as well as links to related municipal policies or amendments.
#
# Accessing this dataset can aid in making informed decisions regarding property development, compliance with zoning laws, and understanding the urban planning landscape of Toronto. In these sets of codes, it will assist in classifying wards in Toronto as low, medium, or high risk for collisions by adding features to assist in predicting the classification.

# %% [markdown]
# ## Setup Notebook

# %%
# Import 3rd party libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV Data

# %%
# Import dataset as a DataFrane
zoning_data = pd.read_csv('Zoning Area - 4326.csv')

# View DataFrame
zoning_data.head()
# Out:
#    _id  GEN_ZONE ZN_ZONE ZN_HOLDING  HOLDING_ID  FRONTAGE  ZN_AREA  UNITS  \
# 0    1         2      UT          N         NaN      -1.0     -1.0   -1.0
# 1    2         1      ON          N         NaN      -1.0     -1.0   -1.0
# 2    3         0      RD          N         NaN      14.0    510.0    NaN
# 3    4         1       O          N         NaN      -1.0     -1.0   -1.0
# 4    5         0      RD          N         NaN       NaN      NaN    NaN
#
#    DENSITY  COVERAGE  ...  ZN_EXCPTN  EXCPTN_NO  STAND_SET  ZN_STATUS  \
# 0     -1.0       NaN  ...          N        NaN       -1.0          2
# 1     -1.0       NaN  ...          N        NaN       -1.0          0
# 2      NaN       NaN  ...          Y     1058.0       -1.0          2
# 3     -1.0       NaN  ...          N        NaN       -1.0          3
# 4      NaN       NaN  ...          Y     1040.0       -1.0          2
#
#                   ZN_STRING AREA_UNITS  ZBL_CHAPT  ZBL_SECTN      ZBL_EXCPTN  \
# 0                        UT       -1.0        100      100.1             NaN
# 1                        ON       -1.0         90       90.2             NaN
# 2  RD (f14.0; a510) (x1058)        NaN         10       10.2  900.3.10(1058)
# 3                         O       -1.0         90       90.1             NaN
# 4                RD (x1040)        NaN         10       10.2  900.3.10(1040)
#
#                                             geometry
# 0  {"type": "MultiPolygon", "coordinates": [[[[-7...
# 1  {"type": "MultiPolygon", "coordinates": [[[[-7...
# 2  {"type": "MultiPolygon", "coordinates": [[[[-7...
# 3  {"type": "MultiPolygon", "coordinates": [[[[-7...
# 4  {"type": "MultiPolygon", "coordinates": [[[[-7...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Let's exploring the zoning data columns (features).

# %%
# Check the number of columns and rows
zoning_data.shape
# Out:
# (11719, 25)

# %%
# Check the columns in DataFrame
zoning_data.columns
# Out:
# Index(['_id', 'GEN_ZONE', 'ZN_ZONE', 'ZN_HOLDING', 'HOLDING_ID', 'FRONTAGE',
#        'ZN_AREA', 'UNITS', 'DENSITY', 'COVERAGE', 'FSI_TOTAL', 'PRCNT_COMM',
#        'PRCNT_RES', 'PRCNT_EMMP', 'PRCNT_OFFC', 'ZN_EXCPTN', 'EXCPTN_NO',
#        'STAND_SET', 'ZN_STATUS', 'ZN_STRING', 'AREA_UNITS', 'ZBL_CHAPT',
#        'ZBL_SECTN', 'ZBL_EXCPTN', 'geometry'],
#       dtype='object')

# %% [markdown]
# From the website that this data was obtained from (https://open.toronto.ca/dataset/zoning-by-law/), the columns describe the following:
#
# - '_id': Unique row identifier for Open Data database.
# - 'GEN_ZONE': The land use category of the lands within the zone boundary. Each 'zone category' has its own Chapter in the text of By-law 569-2013.
# - 'ZN_ZONE': The land use category of the lands within the zone boundary. Each 'zone category' has its own Chapter in the text of By-law 569-2013.  0 = Residential 1 = Open Space 2 = Utility and Transportation 4 = Employment Industrial 5 = Institutional 6 = Commercial Residential Employment 101 = Residential Apartment 201 = Commercial 202 = Commercial Residential
# - 'ZN_HOLDING':To indicate whether there is a HOLDING status for the zone. The zone label will be prefaced by the letter (H). These are not common, and when used, a Holding Zone is most often applied to specific sites. Yes (Y) or No (N)
# - 'HOLDING_ID': Holding number if it exists.
# - 'FRONTAGE': The required minimum Lot Frontage in the zone, and is a numeric value prefaced by the letter 'f' within a residential zone label. Unit = metres
# - 'ZN_AREA':The required minimum Lot Area in the zone, and is a numeric value prefaced by the letter 'a' within a residential zone. Unit = square metres
# - 'UNITS': The permitted maximum number of Dwelling Units allowed on a lot in the zone, and is a numeric value prefaced by the letter 'u' in a residential zone.
# - 'DENSITY': The permitted maximum Density in the zone by FSI (floor space index), and is a numeric value prefaced by the letter 'd' in residential zones.
# - 'COVERAGE': The permitted maximum percentage of a lot that can be covered by any part of any building or structure on or above the surface of the lot. Unit = % (percent)
# - 'FSI_TOTAL': The permitted maximum FSI (floor space index) Total in the zone. It is a numeric value following the zone symbol.
# - 'PRCNT_COMM': The permitted maximum FSI (floor space index) for Commercial Use in most mixed-use zones, and is a numeric value prefaced by letter 'c' in the zone label.
# - 'PRCNT_RES': The permitted maximum FSI (floor space index) for Residential Use in most mixed-use zones, and is a numeric value prefaced by the letter 'r' in the zone label.
# - 'PRCNT_EMMP': The permitted maximum FSI (floor space index) for Employment Uses in the zone, and is a numeric value prefaced by the letter 'e' in the zone label.
# - 'PRCNT_OFFC': The permitted maximum FSI (floor space index) for Office Uses in an Employment-Office zone, and is a numeric value prefaced by the letter 'o' in the zone label.
# - 'ZN_EXCPTN': This indicates whether a zone has an Exception. Yes (Y) or No (N)
# - 'EXCPTN_NO': This is the Exception Number for the zone if one exists. The exception number is prefaced by the letter 'x' in the zone label. Each zone has its own series of exception numbers, starting at 1, so the exception number must be read in conjunction with the respective zone symbol.
# - 'STAND_SET': Set of standards referred to in the Commercial-Residential mixed use zone, based on three different design typologies. The 'standard set' number is prefaced by the letters 'SS' in the zone label.
# - 'ZN_STATUS': Status of the Zone, primarily indicating whether the lands have been incorporated into By-law 569-2013 or not. 0-4 and 6 = In the By-law. 5 = Not Part of Zoning By-law 569-2013
# - 'ZN_STRING': Complete label of the zone.
# - 'AREA_UNITS': This is also a type of density limit, indicating the required minimum lot area per dwelling unit on a lot in the zone. Unit = square metres.
# - 'ZBL_CHAPT': By-law text chapter number
# - 'ZBL_SECTN': By-law text section number
# - 'ZBL_EXCPTN': By-law text exception number

# %% [markdown]
# The following columns will be dropped because they just provide By-law text or exception numbers, which will not help in correlations or identifying patterns in the features and number of collisions of a zone: 'ZBL_CHAPT', 'ZBL_SECTN', 'ZBL_EXCPTN'.

# %%
# Drop columns ZBL_CHAPT', 'ZBL_SECTN', 'ZBL_EXCPTN'
zoning_data = zoning_data.drop(columns = ['ZBL_CHAPT', 'ZBL_SECTN', 'ZBL_EXCPTN', 'EXCPTN_NO'], errors='ignore')

# %%
# Check if columns are removed
zoning_data.columns
# Out:
# Index(['_id', 'GEN_ZONE', 'ZN_ZONE', 'ZN_HOLDING', 'HOLDING_ID', 'FRONTAGE',
#        'ZN_AREA', 'UNITS', 'DENSITY', 'COVERAGE', 'FSI_TOTAL', 'PRCNT_COMM',
#        'PRCNT_RES', 'PRCNT_EMMP', 'PRCNT_OFFC', 'ZN_EXCPTN', 'STAND_SET',
#        'ZN_STATUS', 'ZN_STRING', 'AREA_UNITS', 'geometry'],
#       dtype='object')

# %%
# Check data types per column
print(zoning_data.dtypes)
# Out:
# _id             int64
# GEN_ZONE        int64
# ZN_ZONE        object
# ZN_HOLDING     object
# HOLDING_ID    float64
# FRONTAGE      float64
# ZN_AREA       float64
# UNITS         float64
# DENSITY       float64
# COVERAGE      float64
# FSI_TOTAL     float64
# PRCNT_COMM    float64
# PRCNT_RES     float64
# PRCNT_EMMP    float64
# PRCNT_OFFC    float64
# ZN_EXCPTN      object
# STAND_SET     float64
# ZN_STATUS       int64
# ZN_STRING      object
# AREA_UNITS    float64
# geometry       object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Data cleaning is essential to ensure datasets are accurate, consistent, and free of errors, which improves the reliability of the dataset. It prevents distorted results, enhances performance, and ensures data is easy to interpret and use effectively. The first step is to check if there is missing (null) values in the dataset.

# %%
# Check for missing values
print(zoning_data.isnull().sum())
# Out:
# _id               0
# GEN_ZONE          0
# ZN_ZONE           0
# ZN_HOLDING        0
# HOLDING_ID    10277
# FRONTAGE       3177
# ZN_AREA        3685
# UNITS          5734
# DENSITY        4455
# COVERAGE      11719
# FSI_TOTAL        43
# PRCNT_COMM      463
# PRCNT_RES        25
# PRCNT_EMMP     2291
# PRCNT_OFFC      367
# ZN_EXCPTN         0
# STAND_SET        12
# ZN_STATUS         0
# ZN_STRING         0
# AREA_UNITS     5707
# geometry          0
# dtype: int64

# %% [markdown]
# There is missing data for 'HOLDING_ID', 'FRONTAGE', 'ZN_AREA', 'UNITS', 'DENSITY', 'COVERAGE', 'FSI_TOTAL', 'PRCNT_COMM', 'PRCNT_RES', 'PRCNT_EMMP', 'PRCNT_OFFC', 'STAND_SET', and 'AREA_UNITS'. Let's look at these columsn separately to see hwo to handle them. It is important to make note that there is only 11719 columns.
#
# 'HOLDING_ID': Missing ~88% data and since there is information about the holdign status already ('ZN_HOLDING'), then this column is redundant, unneccesary, and missing far too much data. Therefore, this column will be dropped.
#
# 'COVERAGE': There is no data for this column (permitted maximum percentage of a lot that can be covered by any part of any building or structure), therefore it will be dropped. This could be because there is no coverage information during data collection, data loss during proprocessing, there is no proper survey data avilabel to determine this value, the zones are under construction, or there is a data entry error.
#
# 'AREA_UNITS': This feature does not provide actional insight or significant correlation as it is just a type of density data, with 49% of data missing, therefore it will be dropped.

# %% [markdown]
# For the remaining columns, we will impute the data based on mean or median. To determine which one to use, we will plot the distribution to see if data is skewed or normally distributed. If it is normally distributed, use the mean, if skewed, use the median.

# %%
# Plot distribution of features with missing values (that will not be dropped) to see if uniform or skewed. 
columns_to_plot = ['FRONTAGE', 'ZN_AREA', 'UNITS', 'DENSITY', 'FSI_TOTAL', 
                   'PRCNT_COMM', 'PRCNT_RES', 'PRCNT_EMMP', 'PRCNT_OFFC', 'STAND_SET']


plt.figure(figsize=(20, 20))

for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(4, 3, i)
    plt.hist(zoning_data[column])
    plt.title(column, fontsize = 14)
    plt.xlabel(column)
    plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# All are skewed rather than PRCNT_EMMP and PRCNT_OFFC. Therefore most will use the median while those 2 will use the mean.

# %%
# List of columns to drop
columns_drop = ['HOLDING_ID', 'COVERAGE','AREA_UNITS']

# List of columns to impute with median (skewed data)
columns_median = ['FRONTAGE', 'ZN_AREA', 'UNITS', 'DENSITY', 'FSI_TOTAL', 
                  'PRCNT_COMM', 'PRCNT_RES', 'STAND_SET']

# List of columns to impute with mean (normally distributed data)
columns_mean = ['PRCNT_EMMP', 'PRCNT_OFFC']

# Drop columns
zoning_data = zoning_data.drop(columns=columns_drop, errors='ignore')

# Impute skewed columns with median
zoning_data[columns_median] = zoning_data[columns_median].apply(lambda col: col.fillna(col.median()))

# Impute normally distributed columns with mean
zoning_data[columns_mean] = zoning_data[columns_mean].apply(lambda col: col.fillna(col.mean()))

# %%
# Verify that missing values have been handled
print(zoning_data.isnull().sum())
# Out:
# _id           0
# GEN_ZONE      0
# ZN_ZONE       0
# ZN_HOLDING    0
# FRONTAGE      0
# ZN_AREA       0
# UNITS         0
# DENSITY       0
# FSI_TOTAL     0
# PRCNT_COMM    0
# PRCNT_RES     0
# PRCNT_EMMP    0
# PRCNT_OFFC    0
# ZN_EXCPTN     0
# STAND_SET     0
# ZN_STATUS     0
# ZN_STRING     0
# geometry      0
# dtype: int64

# %% [markdown]
# All missing (null) values have been dealt with (removed or imputed). Let's also remove all duplicates.

# %%
# Remove Duplicates
zoning_data.drop_duplicates(inplace=True)

# %% [markdown]
# Now let's remove outliers with the Interquartile Range method.

# %%
# Function to calculate IQR and remove outliers
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)  # 25th percentile
    Q3 = df[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1                   # Inter-Quartile Range
    
    # Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter out rows with outliers
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# List of numeric columns
numeric_columns = zoning_data.select_dtypes(include=['float64', 'int64']).columns

# Remove outliers using the IQR method
for column in numeric_columns:
    zoning_data = remove_outliers_iqr(zoning_data, column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      12     return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
#      14 # List of numeric columns
# ---> 15 numeric_columns = zoning_data.select_dtypes(include=['float64', 'int64']).columns
#      17 # Remove outliers using the IQR method
#      18 for column in numeric_columns:
#
# NameError: name 'zoning_data' is not defined

# %% [markdown]
# That is all for data cleaning, let's see the new size of the dataset.

# %%
zoning_data.shape

# %%
### FIX
