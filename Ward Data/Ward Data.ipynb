# %% [markdown]
# # City of Toronto Ward Data

# %% [markdown]
# This dataset contains the City of Toronto ward boundaries in the WGS84 coordinate system. Wards are administrative divisions used for political, electoral, and governance purposes. This dataset contains spatial (geographic) and attribute information for each ward in the city. Let's see the shapefile on a folium map.

# %% [markdown]
# ## Setup Notebook

# %%
# Import 3rd party libraries
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import folium
import matplotlib.pylab as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import City of Toronto Ward Shape File

# %%
# Load the shapefile
wards_data = gpd.read_file('WARD_WGS84.shp')

# Create a folium map
map_wards = folium.Map(location=[43.7, -79.4], zoom_start=11)  # Adjust to center on Toronto

# Add the ward shapefile to the map
folium.GeoJson(wards_data, 
               name="Wards"
              ).add_to(map_wards)

# Display the map
map_wards
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c813c7a592ea8dfa1089395d0dc7b45f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c813c7a592ea8dfa1089395d0dc7b45f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c813c7a592ea8dfa1089395d0dc7b45f = L.map(
#                 &quot;map_c813c7a592ea8dfa1089395d0dc7b45f&quot;,
#                 {
#                     center: [43.7, -79.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bae49d175d633f3b9cba63032875d22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8bae49d175d633f3b9cba63032875d22.addTo(map_c813c7a592ea8dfa1089395d0dc7b45f);
#
#
#
#         function geo_json_af80d90a21d6498e1786ac87bac22a02_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_af80d90a21d6498e1786ac87bac22a02 = L.geoJson(null, {
#                 onEachFeature: geo_json_af80d90a21d6498e1786ac87bac22a02_onEachFeature,
#
#         });
#
#         function geo_json_af80d90a21d6498e1786ac87bac22a02_add (data) {
#             geo_json_af80d90a21d6498e1786ac87bac22a02
#                 .addData(data);
#         }
#             geo_json_af80d90a21d6498e1786ac87bac22a02_add({&quot;bbox&quot;: [-79.639264937, 43.580995995, -79.115243191, 43.855457183], &quot;features&quot;: [{&quot;bbox&quot;: [-79.362927809, 43.70300837, -79.300592561, 43.768363303], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-79.313345366, 43.716986164], [-79.319502057, 43.715632174], [-79.319834989, 43.7155908], [-79.320074013, 43.715558394], [-79.320073138, 43.715556565], [-79.319982764, 43.715182858], [-79.32001171, 43.71485434], [-79.320039147, 43.71479463], [-79.320154094, 43.714678468], [-79.320248637, 43.714607172], [-79.320426807, 43.714579165], [-79.320668627, 43.714598022], [-79.320882558, 43.714578052], [-79.320920844, 43.714548559], [-79.320936266, 43.714496871], [-79.320911339, 43.714325073], [-79.320782128, 43.714119868], [-79.320728087, 43.714058841], [-79.320527942, 43.713982791], [-79.320301462, 43.713954726], [-79.320243058, 43.713904763], [-79.320194993, 43.713799422], [-79.320213018, 43.71373481], [-79.320230998, 43.71368128], [-79.320300131, 43.713626078], [-79.320652779, 43.713442114], [-79.320961467, 43.713177059], [-79.32124541, 43.712889461], [-79.321591189, 43.712603044], [-79.321609212, 43.712534742], [-79.321591585, 43.712470075], [-79.32157397, 43.712401716], [-79.321515639, 43.712325895], [-79.32135801, 43.712255469], [-79.321168648, 43.712232232], [-79.320678361, 43.712280958], [-79.320253827, 43.712388295], [-79.320033309, 43.712535914], [-79.319948114,
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...
# 2  POLYGON ((-79.35232 43.71573, -79.35209 43.715...
# 3  POLYGON ((-79.22591 43.8396, -79.22556 43.8394...
# 4  POLYGON ((-79.39004 43.6905, -79.39004 43.6905...

# %% [markdown]
# ## Data Analysis

# %%
wards_data.shape
# Out:
# (25, 10)

# %%
# Check the columns in geoDataFrame
wards_data.columns
# Out:
# Index(['AREA_ID', 'AREA_TYPE', 'AREA_S_CD', 'AREA_L_CD', 'AREA_NAME', 'X', 'Y',
#        'LONGITUDE', 'LATITUDE', 'geometry'],
#       dtype='object')

# %% [markdown]
# The columns describe the following:
# - 'AREA_ID': A unique identifier for each ward in the dataset.
# - 'AREA_TYPE': Indicates the type of area (all is WD18 for wards in the 2018 model of Toronto).
# - 'AREA_S_CD': A short code representing the ward, likely numeric.
# - 'AREA_L_CD': A longer code that may provide additional context or differentiation for the ward.
# - 'AREA_NAME': The official name of the ward.
# - X,y : coordiantes in a projected coordinate system.
# - Longitude, Latitude: Geographic lat and long of the ward's approximate center.
#
# We will drop the following columns:
#
# - 'AREA_ID' is unrequired because we just require the ward classification.
# - 'AREA_TYPE' only contains one unique value, WD18, therefore it is not providing any new data and is unnecessary.
# - X,y: We will be using the geometry, and keep lat and long columns for validation, therefore X,y not necessary.

# %%
# Drop AREA_L_CD
wards_data = wards_data.drop(columns=['AREA_ID', 'AREA_TYPE', 'X', 'Y'])

# Check that it has been removed
wards_data.head()
# Out:
#   AREA_S_CD AREA_L_CD            AREA_NAME  LONGITUDE   LATITUDE  \
# 0        16        16      Don Valley East  -79.33298  43.739716
# 1        03        03  Etobicoke-Lakeshore  -79.52087  43.621646
# 2        15        15      Don Valley West  -79.37536  43.728396
# 3        23        23    Scarborough North  -79.25467  43.809672
# 4        11        11  University-Rosedale  -79.39432  43.671139
#
#                                             geometry
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...
# 2  POLYGON ((-79.35232 43.71573, -79.35209 43.715...
# 3  POLYGON ((-79.22591 43.8396, -79.22556 43.8394...
# 4  POLYGON ((-79.39004 43.6905, -79.39004 43.6905...

# %% [markdown]
# Let's explore the differences between 'AREA_S_CD' and 'AREA_L_CD'.

# %%
wards_data['AREA_S_CD'].unique()
# Out:
# array(['16', '03', '15', '23', '11', '10', '09', '05', '17', '08', '02',
#        '01', '04', '12', '22', '21', '24', '25', '20', '19', '18', '06',
#        '07', '14', '13'], dtype=object)

# %%
wards_data['AREA_L_CD'].unique()
# Out:
# array(['16', '03', '15', '23', '11', '10', '09', '05', '17', '08', '02',
#        '01', '04', '12', '22', '21', '24', '25', '20', '19', '18', '06',
#        '07', '14', '13'], dtype=object)

# %% [markdown]
# There are no differences between the two, therefore only one will be required to display the ward numbers. We will then drop 'AREA_L_CD'.

# %%
# Drop AREA_L_CD
wards_data = wards_data.drop(columns=['AREA_L_CD'])

# Check that it has been removed
wards_data.head()
# Out:
#   AREA_S_CD            AREA_NAME  LONGITUDE   LATITUDE  \
# 0        16      Don Valley East  -79.33298  43.739716
# 1        03  Etobicoke-Lakeshore  -79.52087  43.621646
# 2        15      Don Valley West  -79.37536  43.728396
# 3        23    Scarborough North  -79.25467  43.809672
# 4        11  University-Rosedale  -79.39432  43.671139
#
#                                             geometry
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...
# 2  POLYGON ((-79.35232 43.71573, -79.35209 43.715...
# 3  POLYGON ((-79.22591 43.8396, -79.22556 43.8394...
# 4  POLYGON ((-79.39004 43.6905, -79.39004 43.6905...

# %% [markdown]
# Let's rename columns 'AREA_L_CD' and 'AREA_NAME'

# %%
# Rename columns in the GeoDataFrame
wards_data = wards_data.rename(columns={'AREA_S_CD': 'WARD NUMBER', 'AREA_NAME': 'WARD NAME'})

# Review geoDataFrame
wards_data.head()
# Out:
#   WARD NUMBER            WARD NAME  LONGITUDE   LATITUDE  \
# 0          16      Don Valley East  -79.33298  43.739716
# 1          03  Etobicoke-Lakeshore  -79.52087  43.621646
# 2          15      Don Valley West  -79.37536  43.728396
# 3          23    Scarborough North  -79.25467  43.809672
# 4          11  University-Rosedale  -79.39432  43.671139
#
#                                             geometry
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...
# 2  POLYGON ((-79.35232 43.71573, -79.35209 43.715...
# 3  POLYGON ((-79.22591 43.8396, -79.22556 43.8394...
# 4  POLYGON ((-79.39004 43.6905, -79.39004 43.6905...

# %%
# Check data types per column
print(wards_data.dtypes)
# Out:
# WARD NUMBER      object
# WARD NAME        object
# LONGITUDE       float64
# LATITUDE        float64
# geometry       geometry
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
# Check for missing values
print(wards_data.isnull().sum())
# Check for duplicates
wards_data.duplicated().sum()
# Out:
# WARD NUMBER    0
# WARD NAME      0
# LONGITUDE      0
# LATITUDE       0
# geometry       0
# dtype: int64
# 0

# %% [markdown]
# There are no null or duplicated values to be handled.

# %% [markdown]
# ## Import City of Toronto Community Council Boundaries GeoJson File

# %% [markdown]
# This is a geo-spatial file that outlines the service districts of the City of Toronto. We will combine this with the ward data to group different wards for better understanding and visualization.

# %%
# Load the geojson file
wards_boundaries = gpd.read_file('Community Council Boundaries Data - 4326.geojson')

# Create a folium map
map_wards_boundaries = folium.Map(location=[43.7, -79.4], zoom_start=11)  # Adjust to center on Toronto

# Add the ward shapefile to the map
folium.GeoJson(wards_boundaries, 
               name="Wards"
              ).add_to(map_wards_boundaries)

# Display the map
map_wards_boundaries
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e35b6f7e12b3cdca0e80cdd9fb83476 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e35b6f7e12b3cdca0e80cdd9fb83476&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e35b6f7e12b3cdca0e80cdd9fb83476 = L.map(
#                 &quot;map_5e35b6f7e12b3cdca0e80cdd9fb83476&quot;,
#                 {
#                     center: [43.7, -79.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7083acb0842c1a0a40bd5a726cf546e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7083acb0842c1a0a40bd5a726cf546e.addTo(map_5e35b6f7e12b3cdca0e80cdd9fb83476);
#
#
#
#         function geo_json_9e475a35f95bbe9a655e94f4e7708413_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_
.8078011030671], [-79.1383081212914, 43.8076212417168], [-79.1381632042662, 43.8074947765319], [-79.1378827449159, 43.8075028893579], [-79.1377119571217, 43.8076778606419], [-79.1376114361268, 43.8078620645964], [-79.1373168399238, 43.8078296262359], [-79.1370503040044, 43.8077117747384], [-79.136786882107, 43.8077919388158], [-79.136566742872, 43.8079757616319], [-79.1362604794488, 43.8080737994581], [-79.1358924805503, 43.8080366322371], [-79.1355874892799, 43.8079231463636], [-79.1353057888153, 43.8077467262658], [-79.1350298502106, 43.8075163172395], [-79.1347521955435, 43.8073129143709], [-79.1344842345867, 43.8071140333756], [-79.1342204011108, 43.8069376677202], [-79.1340992289224, 43.806856737949], [-79.1340371751162, 43.8067930634637], [-79.1340076984186, 43.8067047942371],

# %%
wards_boundaries.head()
# Out:
#    _id    AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID AREA_SHORT_CODE  \
# 0    1  2476922.0    26002906.0             0.0              EA
# 1    2  2476921.0    26002905.0             0.0              SO
# 2    3  2476920.0    26002904.0             0.0              NO
# 3    4  2476919.0    26002903.0             0.0              WE
#
#   AREA_LONG_CODE                                AREA_NAME  \
# 0             EA            Scarborough Community Council
# 1             SO  Toronto and East York Community Council
# 2             NO             North York Community Council
# 3             WE         Etobicoke York Community Council
#
#                                  AREA_DESC  OBJECTID  \
# 0            Scarborough Community Council  17503889
# 1  Toronto and East York Community Council  17503905
# 2             North York Community Council  17503921
# 3         Etobicoke York Community Council  17503937
#
#                                             geometry
# 0  MULTIPOLYGON (((-79.15179 43.81409, -79.15174 ...
# 1  MULTIPOLYGON (((-79.29864 43.71515, -79.29837 ...
# 2  MULTIPOLYGON (((-79.31326 43.75221, -79.31302 ...
# 3  MULTIPOLYGON (((-79.48848 43.75333, -79.48834 ...

# %% [markdown]
# The only column that is required is one that provides the name for each service district. We will use AREA_NAME and drop the remaining columns (other than geometry).

# %%
# GeoDataFrame with only AREA_NAME and geometry columns
wards_boundaries= wards_boundaries[['AREA_NAME', 'geometry']]

# View GeoDataFrame
wards_boundaries.head()
# Out:
#                                  AREA_NAME  \
# 0            Scarborough Community Council
# 1  Toronto and East York Community Council
# 2             North York Community Council
# 3         Etobicoke York Community Council
#
#                                             geometry
# 0  MULTIPOLYGON (((-79.15179 43.81409, -79.15174 ...
# 1  MULTIPOLYGON (((-79.29864 43.71515, -79.29837 ...
# 2  MULTIPOLYGON (((-79.31326 43.75221, -79.31302 ...
# 3  MULTIPOLYGON (((-79.48848 43.75333, -79.48834 ...

# %% [markdown]
# Let's explore the AREA_NAME column

# %%
wards_boundaries['AREA_NAME'].unique
# Out:
# <bound method Series.unique of 0              Scarborough Community Council
# 1    Toronto and East York Community Council
# 2               North York Community Council
# 3           Etobicoke York Community Council
# Name: AREA_NAME, dtype: object>

# %% [markdown]
# These names are a mouthful, let us shorten them.

# %%
# Delete 'Community Council' in AREA_NAME
wards_boundaries['AREA_NAME'] = wards_boundaries['AREA_NAME'].str.replace(' Community Council', '', regex=False)

# View GeoDataFrame
wards_boundaries.head()
# Out:
#                AREA_NAME                                           geometry
# 0            Scarborough  MULTIPOLYGON (((-79.15179 43.81409, -79.15174 ...
# 1  Toronto and East York  MULTIPOLYGON (((-79.29864 43.71515, -79.29837 ...
# 2             North York  MULTIPOLYGON (((-79.31326 43.75221, -79.31302 ...
# 3         Etobicoke York  MULTIPOLYGON (((-79.48848 43.75333, -79.48834 ...

# %% [markdown]
# ## Combine Community Council Boundaries with Wards

# %% [markdown]
# First, we must ensure they are in the same coordinate Reference Systems (CRS) in Python / GeoPandas. First, lets see the CRS information for each file.

# %%
print (wards_boundaries.crs)
print (wards_data.crs)
# Out:
# EPSG:4326
# EPSG:4326

# %% [markdown]
# We will now set up the goemetry features to align. First .buffer(0) will fix invalid geometries, such as self-intersections or improper polygon constructions, ensuring the data is valid for spatial operations. Then, .explode() separates multi-part geometries (multi-polygons in wards_boundaries) into individual components, making it easier to handle and analyze each part independently.

# %%
# Fix invalid geometries
wards_boundaries["geometry"] = wards_boundaries["geometry"].buffer(0)
wards_data["geometry"] = wards_data["geometry"].buffer(0)

# Explode multi-part geometries into individual parts
wards_boundaries = wards_boundaries.explode(index_parts=False)

# %% [markdown]
# We will now use spatial operations to determine which wards are in each boundary. A new column 'WARD DISTRICT' will be added in the ward data.

# %%
# Perform a spatial join to add AREA_NAME to wards_data
wards_data_with_district = gpd.sjoin(wards_data, wards_boundaries[['AREA_NAME', 'geometry']], how="left", predicate="intersects")

# Rename AREA_NAME to WARD DISTRICT
wards_data_with_district = wards_data_with_district.rename(columns={'AREA_NAME': 'WARD DISTRICT'})

# Drop unnecessary columns
wards_data_with_district = wards_data_with_district.drop(columns=['index_right'], errors='ignore')

# %%
wards_data_with_district.head()
# Out:
#   WARD NUMBER            WARD NAME  LONGITUDE   LATITUDE  \
# 0          16      Don Valley East  -79.33298  43.739716
# 0          16      Don Valley East  -79.33298  43.739716
# 0          16      Don Valley East  -79.33298  43.739716
# 1          03  Etobicoke-Lakeshore  -79.52087  43.621646
# 1          03  Etobicoke-Lakeshore  -79.52087  43.621646
#
#                                             geometry          WARD DISTRICT
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...  Toronto and East York
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...             North York
# 0  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...            Scarborough
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...  Toronto and East York
# 1  POLYGON ((-79.49777 43.65198, -79.49725 43.651...         Etobicoke York

# %% [markdown]
# Just to clean the data some more, we will change the order of the columns.

# %%
column_order = ['WARD NUMBER', 'WARD NAME', 'WARD DISTRICT', 'LONGITUDE', 'LATITUDE', 'geometry']
wards_data_with_district = wards_data_with_district[column_order]

# View GeoDataFrame
wards_data_with_district.head()
# Out:
#   WARD NUMBER            WARD NAME          WARD DISTRICT  LONGITUDE  \
# 0          16      Don Valley East  Toronto and East York  -79.33298
# 0          16      Don Valley East             North York  -79.33298
# 0          16      Don Valley East            Scarborough  -79.33298
# 1          03  Etobicoke-Lakeshore  Toronto and East York  -79.52087
# 1          03  Etobicoke-Lakeshore         Etobicoke York  -79.52087
#
#     LATITUDE                                           geometry
# 0  43.739716  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 0  43.739716  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 0  43.739716  POLYGON ((-79.31335 43.71699, -79.3195 43.7156...
# 1  43.621646  POLYGON ((-79.49777 43.65198, -79.49725 43.651...
# 1  43.621646  POLYGON ((-79.49777 43.65198, -79.49725 43.651...

# %%
wards_data_with_district.shape
# Out:
# (49, 6)

# %%
wards_data.shape
# Out:
# (25, 5)

# %% [markdown]
# After an initial analysis, it is clear that there are some wards that belong in more than one district. We will assign a district to each ward by determining the major area that each ward intersects a district.

# %%
# Perform an intersection analysis to calculate overlap areas
intersection = gpd.overlay(wards_data_with_district, wards_boundaries, how='intersection')

# Calculate the area of the intersection geometries
intersection['intersection_area'] = intersection['geometry'].area

# For each ward, find the district with the maximum intersection area
wards_data_with_district = (
    intersection.loc[intersection.groupby('WARD NUMBER')['intersection_area'].idxmax()]
    [['WARD NUMBER', 'WARD NAME', 'AREA_NAME', 'geometry']]  # Keep relevant columns
    .rename(columns={'AREA_NAME': 'WARD DISTRICT'})  
)

# View GeoDataFrame
wards_data_with_district.head()
# Out:
#    WARD NUMBER            WARD NAME          WARD DISTRICT  \
# 58          01      Etobicoke North         Etobicoke York
# 55          02     Etobicoke Centre         Etobicoke York
# 10          03  Etobicoke-Lakeshore         Etobicoke York
# 59          04   Parkdale-High Park  Toronto and East York
# 34          05    York South-Weston         Etobicoke York
#
#                                              geometry
# 58  POLYGON ((-79.57925 43.76221, -79.57907 43.762...
# 55  POLYGON ((-79.52597 43.7016, -79.52597 43.7016...
# 10  POLYGON ((-79.49725 43.65197, -79.49689 43.651...
# 59  POLYGON ((-79.46615 43.66727, -79.46536 43.667...
# 34  POLYGON ((-79.46888 43.70629, -79.46884 43.706...

# %%
wards_data_with_district.shape
# Out:
# (25, 4)

# %% [markdown]
# We will then set the WARD NUMBER as the index

# %%
# Set WARD NUMBER as the index
wards_data_with_district = wards_data_with_district.set_index('WARD NUMBER')

# View GeoDataFrame
wards_data_with_district.head()
# Out:
#                        WARD NAME          WARD DISTRICT  \
# WARD NUMBER
# 01               Etobicoke North         Etobicoke York
# 02              Etobicoke Centre         Etobicoke York
# 03           Etobicoke-Lakeshore         Etobicoke York
# 04            Parkdale-High Park  Toronto and East York
# 05             York South-Weston         Etobicoke York
#
#                                                       geometry
# WARD NUMBER
# 01           POLYGON ((-79.57925 43.76221, -79.57907 43.762...
# 02           POLYGON ((-79.52597 43.7016, -79.52597 43.7016...
# 03           POLYGON ((-79.49725 43.65197, -79.49689 43.651...
# 04           POLYGON ((-79.46615 43.66727, -79.46536 43.667...
# 05           POLYGON ((-79.46888 43.70629, -79.46884 43.706...

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Output the file to be used with other files

# %%
output_path = "../Clean Data/wards_data.geojson"
wards_data.to_file(output_path, driver="GeoJSON")
